# %% [markdown]
# ## notebook to interact with google cloud bigquery tables

# %%
from google.cloud import storage, bigquery
import google.auth
import pandas as pd

from shapely.geometry import Polygon
from pyproj import Transformer
import requests

# Get default credentials
credentials, project_id = google.auth.default()

# Initialize clients
bq_client = bigquery.Client(credentials=credentials, project=project_id)
storage_client = storage.Client(credentials=credentials, project=project_id)

# %% [markdown]
# ## read tables

# %%
# List all datasets in the project
print(f"Project ID: {project_id}")
print("\nDatasets in project:")
datasets = list(bq_client.list_datasets())

if datasets:
    for dataset in datasets:
        print(f"  - {dataset.dataset_id}")
        
        # List tables in each dataset
        dataset_ref = bq_client.dataset(dataset.dataset_id)
        tables = list(bq_client.list_tables(dataset_ref))
        
        if tables:
            print(f"{len(tables)} Tables in {dataset.dataset_id}:")
            for table in tables:
                print(f"      - {table.table_id}")
        else:
            print(f"    No tables in {dataset.dataset_id}")
        print()
else:
    print("No datasets found in this project.")
# Out:
# Project ID: useful-theory-442820-q8
#
# Datasets in project:
#   - shoreline_metadata
# 2 Tables in shoreline_metadata:
#       - islands
#       - shoreline_data

# %% [markdown]
# ## functions

# %%
def load_geojson_from_url(url):
    """Load GeoJSON data from a public URL."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        st.warning(f"Could not load GeoJSON from {url}: {e}")
        return None
    
def _calculate_shoreline_area(coordinates) -> float:
    """Calculate approximate area of shoreline square meters."""
    total_area = 0.0
    try:
        from shapely.geometry import Polygon
        from pyproj import Transformer
        
        # Convert coordinates to a projected system for area calculation
        transformer = Transformer.from_crs("EPSG:4326", "EPSG:32643", always_xy=True)
        projected_coords = [transformer.transform(lon, lat) for lon, lat in coordinates]
        
        # Create polygon and calculate area
        polygon = Polygon(projected_coords)
        total_area = polygon.area  # Area in square meters

        return total_area
    except Exception as e:
        return total_area

# %% [markdown]
# ## update tables

# %%
# read the shoreline table
for table in tables:
    if table.table_id == "shoreline_data":
        shoreline_table = table
        break
# create a dataframe from shoreline_table
if shoreline_table:
    area_df = bq_client.list_rows(shoreline_table).to_dataframe()
else:
    print("Shoreline table not found.")

# %%
# for each row in area_df, update the shoreline_data table with the area value
for index, row in area_df.iterrows():
    # get the geojson from google cloud storage
    geojson = load_geojson_from_url(row['geojson_path'])

    # get the coordinates from the geojson
    coordinates = geojson['features'][0]['geometry']['coordinates']
    # calculate the area in square meters

    area_sq_meters = _calculate_shoreline_area(coordinates)
    
    print(f"Calculated area for row {index}: {area_sq_meters} square meters")

    update_query = f"""
    UPDATE `useful-theory-442820-q8.shoreline_metadata.shoreline_data`
    SET area_enclosed_m2 = {area_sq_meters}
    WHERE site_id = '{row['site_id']}' AND timestamp = '{row['timestamp']}'
    """
    result = bq_client.query(update_query)
    print(f"Updated {result.num_dml_affected_rows} rows for site_id = {row['site_id']} and timestamp = {row['timestamp']}")
# Out:
# Calculated area for row 0: 50221.30690142016 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-03-08 05:37:11+00:00
# Calculated area for row 1: 49159.66083195888 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-03-08 05:37:11+00:00
# Calculated area for row 1: 49159.66083195888 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-07 05:37:11+00:00
# Calculated area for row 2: 51673.385066325325 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-07 05:37:11+00:00
# Calculated area for row 2: 51673.385066325325 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-17 05:37:21+00:00
# Calculated area for row 3: 50796.59574612601 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-17 05:37:21+00:00
# Calculated area for row 3: 50796.59574612601 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-27 05:37:21+00:00
# Calculated area for row 4: 51798.38760843576 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-27 05:37:21+00:00
# Calculated area for row 4: 51798.38760843576 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-08-25 05:37:21+00:00
# Calculated area for row 5: 51982.322216793815 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-08-25 05:37:21+00:00
# Calculated area for row 5: 51982.322216793815 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-01-27 05:37:09+00:00
# Calculated area for row 6: 51152.75499767297 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-01-27 05:37:09+00:00
# Calculated area for row 6: 51152.75499767297 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-03-03 05:37:11+00:00
# Calculated area for row 7: 52035.702575615665 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-03-03 05:37:11+00:00
# Calculated area for row 7: 52035.702575615665 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-04-07 05:37:19+00:00
# Calculated area for row 8: 52378.22760290595 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-04-07 05:37:19+00:00
# Calculated area for row 8: 52378.22760290595 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-11-23 05:37:19+00:00
# Calculated area for row 9: 51467.898719647026 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-11-23 05:37:19+00:00
# Calculated area for row 9: 51467.898719647026 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-03-13 05:37:19+00:00
# Calculated area for row 10: 52484.49068608864 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-03-13 05:37:19+00:00
# Calculated area for row 10: 52484.49068608864 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-06-01 05:37:29+00:00
# Calculated area for row 11: 51870.29952949521 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-06-01 05:37:29+00:00
# Calculated area for row 11: 51870.29952949521 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-08-20 05:37:19+00:00
# Calculated area for row 12: 50583.701372846495 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-08-20 05:37:19+00:00
# Calculated area for row 12: 50583.701372846495 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-09-09 05:37:19+00:00
# Calculated area for row 13: 51262.26304230049 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-09-09 05:37:19+00:00
# Calculated area for row 13: 51262.26304230049 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-09-19 05:37:19+00:00
# Calculated area for row 14: 52426.5575474445 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-09-19 05:37:19+00:00
# Calculated area for row 14: 52426.5575474445 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-12-03 05:37:21+00:00
# Calculated area for row 15: 50047.990236042795 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-12-03 05:37:21+00:00
# Calculated area for row 15: 50047.990236042795 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-12-13 05:37:11+00:00
# Calculated area for row 16: 50792.86018949753 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-12-13 05:37:11+00:00
# Calculated area for row 16: 50792.86018949753 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2020-11-12 05:37:19+00:00
# Calculated area for row 17: 52258.978741773026 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2020-11-12 05:37:19+00:00
# Calculated area for row 17: 52258.978741773026 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2020-11-27 05:37:21+00:00
# Calculated area for row 18: 49956.62238085007 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2020-11-27 05:37:21+00:00
# Calculated area for row 18: 49956.62238085007 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-03-07 05:37:21+00:00
# Calculated area for row 19: 47714.86865020394 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-03-07 05:37:21+00:00
# Calculated area for row 19: 47714.86865020394 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-04-06 05:37:11+00:00
# Calculated area for row 20: 50694.407954614195 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-04-06 05:37:11+00:00
# Calculated area for row 20: 50694.407954614195 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-05-01 05:37:09+00:00
# Calculated area for row 21: 48320.25020412744 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-05-01 05:37:09+00:00
# Calculated area for row 21: 48320.25020412744 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-01-31 05:20:41+00:00
# Calculated area for row 22: 52583.111271207636 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-01-31 05:20:41+00:00
# Calculated area for row 22: 52583.111271207636 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-03-27 05:16:49+00:00
# Calculated area for row 23: 47091.044872488696 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-03-27 05:16:49+00:00
# Calculated area for row 23: 47091.044872488696 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-04-26 05:16:49+00:00
# Calculated area for row 24: 57054.755673978005 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-04-26 05:16:49+00:00
# Calculated area for row 24: 57054.755673978005 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-06-05 05:16:49+00:00
# Calculated area for row 25: 53096.113947696846 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-06-05 05:16:49+00:00
# Calculated area for row 25: 53096.113947696846 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-11-22 05:21:19+00:00
# Calculated area for row 26: 52651.968709299945 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-11-22 05:21:19+00:00
# Calculated area for row 26: 52651.968709299945 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2023-02-20 05:18:39+00:00
# Calculated area for row 27: 53643.87055017286 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2023-02-20 05:18:39+00:00
# Calculated area for row 27: 53643.87055017286 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-02-15 05:19:19+00:00
# Calculated area for row 28: 51927.02709692804 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-02-15 05:19:19+00:00
# Calculated area for row 28: 51927.02709692804 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-02-20 05:18:41+00:00
# Calculated area for row 29: 51130.41907619971 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-02-20 05:18:41+00:00
# Calculated area for row 29: 51130.41907619971 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-03-08 05:37:11+00:00
# Calculated area for row 30: 47949.44080299307 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-03-08 05:37:11+00:00
# Calculated area for row 30: 47949.44080299307 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-07 05:37:11+00:00
# Calculated area for row 31: 53873.43319198096 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-07 05:37:11+00:00
# Calculated area for row 31: 53873.43319198096 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-17 05:37:21+00:00
# Calculated area for row 32: 41603.23383955589 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-17 05:37:21+00:00
# Calculated area for row 32: 41603.23383955589 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-27 05:37:21+00:00
# Calculated area for row 33: 49039.69965425983 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-04-27 05:37:21+00:00
# Calculated area for row 33: 49039.69965425983 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-08-25 05:37:21+00:00
# Calculated area for row 34: 54221.55402163202 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2017-08-25 05:37:21+00:00
# Calculated area for row 34: 54221.55402163202 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-01-27 05:37:09+00:00
# Calculated area for row 35: 43302.40856874218 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-01-27 05:37:09+00:00
# Calculated area for row 35: 43302.40856874218 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-03-03 05:37:11+00:00
# Calculated area for row 36: 55655.94245374949 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-03-03 05:37:11+00:00
# Calculated area for row 36: 55655.94245374949 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-04-07 05:37:19+00:00
# Calculated area for row 37: 43769.2318806765 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-04-07 05:37:19+00:00
# Calculated area for row 37: 43769.2318806765 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-11-23 05:37:19+00:00
# Calculated area for row 38: 54605.88978945743 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2018-11-23 05:37:19+00:00
# Calculated area for row 38: 54605.88978945743 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-03-13 05:37:19+00:00
# Calculated area for row 39: 47965.24714849875 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-03-13 05:37:19+00:00
# Calculated area for row 39: 47965.24714849875 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-06-01 05:37:29+00:00
# Calculated area for row 40: 51578.441532687066 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-06-01 05:37:29+00:00
# Calculated area for row 40: 51578.441532687066 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-08-20 05:37:19+00:00
# Calculated area for row 41: 50396.240722816445 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-09-09 05:37:19+00:00
# Calculated area for row 42: 50833.675720830965 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-08-20 05:37:19+00:00
# Calculated area for row 41: 50396.240722816445 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-09-09 05:37:19+00:00
# Calculated area for row 42: 50833.675720830965 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-09-19 05:37:19+00:00
# Calculated area for row 43: 55802.514847391 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-12-03 05:37:21+00:00
# Calculated area for row 44: 43289.560425844735 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-09-19 05:37:19+00:00
# Calculated area for row 43: 55802.514847391 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-12-03 05:37:21+00:00
# Calculated area for row 44: 43289.560425844735 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-12-13 05:37:11+00:00
# Calculated area for row 45: 47586.54179704019 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2020-11-12 05:37:19+00:00
# Calculated area for row 46: 47697.451581035624 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2019-12-13 05:37:11+00:00
# Calculated area for row 45: 47586.54179704019 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2020-11-12 05:37:19+00:00
# Calculated area for row 46: 47697.451581035624 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2020-11-27 05:37:21+00:00
# Calculated area for row 47: 54263.431575116694 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-03-07 05:37:21+00:00
# Calculated area for row 48: 50565.967999177636 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2020-11-27 05:37:21+00:00
# Calculated area for row 47: 54263.431575116694 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-03-07 05:37:21+00:00
# Calculated area for row 48: 50565.967999177636 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-04-06 05:37:11+00:00
# Calculated area for row 49: 50607.009760508605 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-05-01 05:37:09+00:00
# Updated None rows for site_id = Fenfushi and timestamp = 2021-04-06 05:37:11+00:00
# Calculated area for row 49: 50607.009760508605 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2021-05-01 05:37:09+00:00
# Calculated area for row 50: 41874.78703321353 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-01-31 05:20:41+00:00
# Calculated area for row 51: 54639.8474491049 square meters
# Calculated area for row 50: 41874.78703321353 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-01-31 05:20:41+00:00
# Calculated area for row 51: 54639.8474491049 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-03-27 05:16:49+00:00
# Calculated area for row 52: 47112.2253126624 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-04-26 05:16:49+00:00
# Calculated area for row 53: 60738.33899031049 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-03-27 05:16:49+00:00
# Calculated area for row 52: 47112.2253126624 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-04-26 05:16:49+00:00
# Calculated area for row 53: 60738.33899031049 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-06-05 05:16:49+00:00
# Calculated area for row 54: 46007.90699437726 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-06-05 05:16:49+00:00
# Calculated area for row 54: 46007.90699437726 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-11-22 05:21:19+00:00
# Calculated area for row 55: 44979.2706781387 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2022-11-22 05:21:19+00:00
# Calculated area for row 55: 44979.2706781387 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2023-02-20 05:18:39+00:00
# Calculated area for row 56: 45474.44498718906 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2023-02-20 05:18:39+00:00
# Calculated area for row 56: 45474.44498718906 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-26 05:21:09+00:00
# Calculated area for row 57: 49582.33575011318 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-26 05:21:09+00:00
# Calculated area for row 57: 49582.33575011318 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-21 05:21:11+00:00
# Calculated area for row 58: 50190.05533820191 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-21 05:21:11+00:00
# Calculated area for row 58: 50190.05533820191 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-16 05:21:49+00:00
# Calculated area for row 59: 53804.55280822545 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-16 05:21:49+00:00
# Calculated area for row 59: 53804.55280822545 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-16 05:21:49+00:00
# Calculated area for row 60: 49604.798930569414 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-16 05:21:49+00:00
# Calculated area for row 60: 49604.798930569414 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-21 05:21:11+00:00
# Calculated area for row 61: 40197.52610145198 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-21 05:21:11+00:00
# Calculated area for row 61: 40197.52610145198 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-26 05:21:09+00:00
# Calculated area for row 62: 57811.204929157066 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-01-26 05:21:09+00:00
# Calculated area for row 62: 57811.204929157066 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-02-15 05:19:19+00:00
# Calculated area for row 63: 50952.55375102989 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-02-15 05:19:19+00:00
# Calculated area for row 63: 50952.55375102989 square meters
# Updated None rows for site_id = Fenfushi and timestamp = 2024-02-20 05:18:41+00:00
# Updated None rows for site_id = Fenfushi and timestamp = 2024-02-20 05:18:41+00:00

# %%
# read the updated shoreline table
area_df_updated = bq_client.list_rows(shoreline_table).to_dataframe()
print(area_df_updated.head())
# Out:
#     site_id                 timestamp                   date_processed  \
# 0  Fenfushi 2017-03-08 05:37:11+00:00 2025-10-24 18:32:09.047625+00:00
# 1  Fenfushi 2021-03-07 05:37:21+00:00 2025-10-24 18:32:14.108813+00:00
# 2  Fenfushi 2019-09-09 05:37:19+00:00 2025-10-24 18:32:12.443998+00:00
# 3  Fenfushi 2023-02-20 05:18:39+00:00 2025-10-24 18:32:16.298262+00:00
# 4  Fenfushi 2021-04-06 05:37:11+00:00 2025-10-24 18:32:14.292552+00:00
#
#                                         geojson_path  \
# 0  https://storage.googleapis.com/littoral-public...
# 1  https://storage.googleapis.com/littoral-public...
# 2  https://storage.googleapis.com/littoral-public...
# 3  https://storage.googleapis.com/littoral-public...
# 4  https://storage.googleapis.com/littoral-public...
#
#                                  simplified_geometry  shoreline_length_m  \
# 0  LINESTRING(72.9021088839923 5.3809810065243, 7...         1076.378547
# 1  LINESTRING(72.9020162678987 5.38090860982317, ...         1123.491893
# 2  LINESTRING(72.9018120398623 5.38100873571534, ...         1064.443067
# 3  LINESTRING(72.9020385374427 5.38101542121009, ...         1038.631431
# 4  LINESTRING(72.9018234021333 5.38095491543883, ...         1049.584814
#
#    area_enclosed_m2  tide_height_m  tide_corrected  cloud_coverage_percent  \
# 0               NaN            NaN            True                     NaN
# 1               NaN            NaN            True                     NaN
# 2               NaN            NaN            True                     NaN
# 3               NaN            NaN            True                     NaN
# 4               NaN            NaN            True                     NaN
#
#    quality_score                 processing_pipeline_version  \
# 0            NaN  littoral_pipeline_v2_standardized_metadata
# 1            NaN  littoral_pipeline_v2_standardized_metadata
# 2            NaN  littoral_pipeline_v2_standardized_metadata
# 3            NaN  littoral_pipeline_v2_standardized_metadata
# 4            NaN  littoral_pipeline_v2_standardized_metadata
#
#                                             metadata
# 0  {"coordinate_system":"WGS84 (EPSG:4326)","coor...
# 1  {"coordinate_system":"WGS84 (EPSG:4326)","coor...
# 2  {"coordinate_system":"WGS84 (EPSG:4326)","coor...
# 3  {"coordinate_system":"WGS84 (EPSG:4326)","coor...
# 4  {"coordinate_system":"WGS84 (EPSG:4326)","coor...
